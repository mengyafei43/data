# %%
import json

# %%
with open("/home/myn1szh/AI_2021/sign-plate-detection/sign-plate-detection_train.json") as jf:
    train_ds = json.load(jf)
with open("/home/myn1szh/AI_2021/sign-plate-detection/sign-plate-detection_test.json") as jf2:
    test_ds = json.load(jf2)

# %%
train_ds.keys()
# Out:
# dict_keys(['images', 'categories', 'annotations'])

# %%
test_ds.keys()
# Out:
# dict_keys(['images', 'categories'])

# %%
len(train_ds["images"])
# Out:
# 1000

# %%
len(train_ds["categories"])

# %%
train_ds["categories"][0]
# Out:
# {'id': 1, 'name': 'Text'}

# %%
len(train_ds["categories"])
# Out:
# 1

# %%
len(train_ds["annotations"])

# %%
len(test_ds["images"])
# Out:
# 1632

# %%
len(test_ds["categories"])

# %%
test_ds["categories"][0]

# %%
train_ds["images"][0]
# Out:
# {'id': 0, 'width': 200, 'height': 200, 'file_name': 'img_000011182_c0_1.png'}

# %%
train_ds["annotations"][0]

# %%
train_ds["annotations"]
# Out:
# [{'id': 0,
#   'image_id': 0,
#   'iscrowd': 0,
#   'ignore': 0,
#   'category_id': 1,
#   'area': 1280.0,
#   'bbox': [80.0, 16.0, 40.0, 32.0]},
#  {'id': 1,
#   'image_id': 1,
#   'iscrowd': 0,
#   'ignore': 0,
#   'category_id': 1,
#   'area': 780.0,
#   'bbox': [88.0, 4.0, 26.0, 30.0]},
#  {'id': 2,
#   'image_id': 2,
#   'iscrowd': 0,
#   'ignore': 0,
#   'category_id': 1,
#   'area': 672.0,
#   'bbox': [80.0, 4.0, 21.0, 32.0]},
#  {'id': 3,
#   'image_id': 4,
#   'iscrowd': 0,
#   'ignore': 0,
#   'category_id': 1,
#   'area': 352.0,
#   'bbox': [93.0, 11.0, 16.0, 22.0]},
#  {'id': 4,
#   'image_id': 4,
#   'iscrowd': 0,
#   'ignore': 0,
#   'category_id': 1,
#   'area': 209.0,
#   'bbox': [135.0, 138.0, 11.0, 19.0]},
#  {'id': 5,
#   'image_id': 4,
#   'iscrowd': 0,
#   'ignore': 0,
#   'category_id': 1,
#   'area': 266.0,
#   'bbox': [76.0, 53.0, 14.0, 19.0]},
#  {'id': 6,
#   'image_id': 5,
#   'iscrowd': 0,
#   'ignore': 0,
#   'category_id': 1,
#   'area': 884.0,
# ...

# %%
for i in range(1000):
    if train_ds["images"][i]["width"] != 200:
        print(i)

# %%
for i in range(1000):
    if train_ds["images"][i]["height"] != 200:
        print(i)

# %%
import cv2

# %%
fn = "/home/myn1szh/AI_2021/sign-plate-detection/images/" + train_ds["images"][0]["file_name"]

# %%
fn
# Out:
# '/home/myn1szh/AI_2021/sign-plate-detection/images/img_000011182_c0_1.png'

# %%
img = cv2.imread(fn)

# %%
img.shape
# Out:
# (200, 200, 3)

# %%
test_ds["images"][0]["file_name"]
# Out:
# 'img_000045191_c0_2.png'

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-d35c46f8d1a2> in <module>()
# ----> 1 import pytorch
#
# ModuleNotFoundError: No module named 'pytorch'

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-d6579f534729> in <module>()
# ----> 1 import tensorflow
#
# ModuleNotFoundError: No module named 'tensorflow'
